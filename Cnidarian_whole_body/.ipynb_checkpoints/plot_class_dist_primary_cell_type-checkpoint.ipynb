# %%
library(tidyverse)

# %%
source("/nfs/research/irene/ysong/MY_BIN/ggplot_themes.r")
# Out:
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
# Loading required package: viridisLite
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:viridis’:
#
#     viridis_pal
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
hvul <- read_csv("metacell_Hvul_geo_1e6_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...12`
# Rows: 16920 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): gene...1, groups_expressed, groups_not_expressed, gene...12, exps_...
# dbl (17): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, tau, lim, n_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
nvec = read_csv("metacell_Nvec_geo_1e6_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...12`
# Rows: 33973 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): gene...1, groups_expressed, groups_not_expressed, gene...12, exps_...
# dbl (17): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, tau, lim, n_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
spis = read_csv("metacell_Spis_geo_1e6_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...12`
# Rows: 37380 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): gene...1, groups_expressed, groups_not_expressed, gene...12, exps_...
# dbl (17): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, tau, lim, n_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
xesp = read_csv("metacell_Xesp_geo_1e6_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...12`
# Rows: 30810 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): gene...1, groups_expressed, groups_not_expressed, gene...12, exps_...
# dbl (17): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, tau, lim, n_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
xboc = read_csv("/nfs/research/irene/ysong/DATA/Cnidarians/Xbocki_single_cell_atlas/metacell_Xboc_geo_1e6_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...12`
# Rows: 12611 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): gene...1, groups_expressed, groups_not_expressed, gene...12, exps_...
# dbl (17): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, tau, lim, n_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
xboc_genespectra = xboc %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Xboc genespectrs classes, MARS-seq') + common_45x
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”

# %%
xboc_tau = xboc  %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw()  +
labs(title = 'Xboc genespectrs classes, MARS-seq')

# %%
spis_genespectra = spis %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Spis genespectrs classes, MARS-seq') + common_45x
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”

# %%
spis_tau = spis  %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw()  +
labs(title = 'Spis genespectrs classes, MARS-seq')

# %%
hvul_genespectra = hvul %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Hvul genespectrs classes, DROP-seq') + common_45x

hvul_tau = hvul  %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw() +
labs(title = 'Hvul genespectrs classes, DROP-seq')
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”

# %%
nvec_genespectra = nvec %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Nvec genespectrs classes, MARS-seq') + common_45x

nvec_tau = nvec  %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw() +
labs(title = 'Nvec genespectrs classes, MARS-seq')


xesp_genespectra = xesp %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Xesp genespectrs classes, 10X v3') + common_45x

xesp_tau = xesp  %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw() +
labs(title = 'Xesp genespectrs classes, 10X v3')
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”

# %%
## Hydra: drop-seq
## Xenia: 10x 2' or 3'
## Nvec: MARS-seq
## Spis: MARS-seq

# %%
library(cowplot)

# %%
fig_genespectra = plot_grid(spis_genespectra, nvec_genespectra, xboc_genespectra, xesp_genespectra, hvul_genespectra, nrow = 2)

# %%
pdf("genespectra_4_species.pdf", height = 10, width = 14)
fig_genespectra
dev.off()
# Out:
# png
#   2

# %%
fig_tau = plot_grid(spis_tau, nvec_tau, xboc_tau, xesp_tau, hvul_tau, nrow = 2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
pdf("tau_4_species.pdf", height = 8, width = 11)
fig_tau
dev.off()
# Out:
# png
#   2

# %%
# so apparently Nvec and Spis have a similar distribution while not the other two

# %%
hvul_old <- read_csv("metacell_Hvul_none_1lim_4fold_classes.csv")
# Out:
# New names:
# • `gene` -> `gene...1`
# • `gene` -> `gene...11`
# Rows: 16920 Columns: 28
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (12): gene...1, groups_expressed, groups_not_expressed, gene...11, exps_...
# dbl (16): mean_exp, min_exp, max_exp, max_2nd, n_exp, frac_exp, lim, n_over,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
hvul_old %>% 
ggplot(aes(x = spec_category)) +
geom_histogram(stat = 'count')
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

# %%
nvec %>% filter(gene...1 %in% ortho_selected$gene1) %>% select(gene...1, spec_category) %>% 
merge(ortho_selected, by.x = 'gene...1', by.y = 'gene1') %>% 
merge((hvul %>% filter(gene...1 %in% ortho_selected$gene2) %>% select(gene...1, spec_category)), by.x = 'gene2', by.y = 'gene...1') %>% 
group_by(spec_category.x, spec_category.y) %>% count() %>% 
ggplot(aes(x = spec_category.x, y = spec_category.y	, fill = n)) +
geom_tile() +
geom_text(aes(label  = n))
# Out:
# plot without title

# %%
ortho <- read_tsv("orthologous_pairs.txt", col_names = c("gene1", "gene2"))
# Out:
# Rows: 16623794 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): Mmus_ENSMUSG00000020679, Hsap_ENSG00000275410_HNF1B
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
nvec_hvul_ortho = ortho %>% filter(((gene1 %in% nvec[['gene...1']]) & (gene2 %in% hvul[['gene...1']])) | ((gene2 %in% nvec[['gene...1']]) & (gene1 %in% hvul[['gene...1']])))

# %%
head(nvec_hvul_ortho)
# Out:
#   gene1          gene2
# 1 Nvec_v1g163982 Hvul_g10365_1
# 2 Nvec_v1g146660 Hvul_g10365_1
# 3 Nvec_v1g180263 Hvul_g24804_1
# 4 Nvec_v1g145386 Hvul_g24804_1
# 5 Nvec_v1g144800 Hvul_g8326_1
# 6 Nvec_v1g115070 Hvul_g8326_1

# %%
hvul %>% filter(gene...1 %in% ortho_selected$gene2) %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Hvul genespectrs classes, DROP-seq') + common_45x

hvul %>% filter(gene...1 %in% ortho_selected$gene2) %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw() +
labs(title = 'Hvul genespectrs classes, DROP-seq')
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
nvec %>% filter(gene...1 %in% ortho_selected$gene1) %>% 
ggplot(aes(x = spec_category, fill = spec_category)) +
geom_histogram(stat = 'count') +theme_bw() +
labs(title = 'Nvec genespectrs classes, MARS-seq') + common_45x

nvec %>% 
filter(tau_category	!= 'lowly expressed') %>% 
ggplot(aes(x = tau)) + 
geom_histogram() + theme_bw()+
labs(title = 'Nvec genespectrs classes, MARS-seq')
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
nvec_spis_ortho = ortho %>% filter(((gene1 %in% nvec[['gene...1']]) & (gene2 %in% spis[['gene...1']])) | ((gene2 %in% nvec[['gene...1']]) & (gene1 %in% spis[['gene...1']])))

# %%
xesp_spis_ortho = ortho %>% filter(((gene1 %in% xesp[['gene...1']]) & (gene2 %in% spis[['gene...1']])) | ((gene2 %in% xesp[['gene...1']]) & (gene1 %in% spis[['gene...1']])))

# %%
hvul_xesp_ortho = ortho %>% filter(((gene1 %in% xesp[['gene...1']]) & (gene2 %in% hvul[['gene...1']])) | ((gene2 %in% xesp[['gene...1']]) & (gene1 %in% hvul[['gene...1']])))

# %%
head(hvul_xesp_ortho)
# Out:
#   gene1       gene2
# 1 Xesp_008452 Hvul_g10365_1
# 2 Xesp_000799 Hvul_g24804_1
# 3 Xesp_018027 Hvul_g8326_1
# 4 Xesp_022339 Hvul_g14066_1
# 5 Xesp_007866 Hvul_g17484_1
# 6 Xesp_007868 Hvul_g17484_1

# %%
ortho_all = merge(merge(nvec_spis_ortho, xesp_spis_ortho, by='gene2'), hvul_xesp_ortho, by.x = 'gene1.y', by.y = 'gene1')

# %%
colnames(ortho_all) = c("xesp", "spis", "nvec", "hvul")

# %%
ortho_all[, c( "spis", "nvec", "xesp", "hvul")]
# Out:
#         spis                nvec           xesp        hvul
# 1       Spis_XP_022793278_1 Nvec_NVE21772  Xesp_000011 Hvul_g15501_1
# 2       Spis_XP_022779104_1 Nvec_v1g150412 Xesp_000012 Hvul_g31735_1
# 3       Spis_XP_022779105_1 Nvec_v1g150412 Xesp_000012 Hvul_g31735_1
# 4       Spis_XP_022779181_1 Nvec_v1g154148 Xesp_000012 Hvul_g31735_1
# 5       Spis_XP_022779181_1 Nvec_v1g230013 Xesp_000012 Hvul_g31735_1
# 6       Spis_XP_022779105_1 Nvec_v1g173595 Xesp_000012 Hvul_g31735_1
# 7       Spis_XP_022779133_1 Nvec_v1g154148 Xesp_000012 Hvul_g31735_1
# 8       Spis_XP_022792377_1 Nvec_v1g110362 Xesp_000012 Hvul_g31735_1
# 9       Spis_XP_022779104_1 Nvec_v1g173595 Xesp_000012 Hvul_g31735_1
# 10      Spis_XP_022786829_1 Nvec_v1g185797 Xesp_000020 Hvul_g15231_1
# 11      Spis_XP_022786829_1 Nvec_v1g112864 Xesp_000020 Hvul_g15231_1
# 12      Spis_XP_022793278_1 Nvec_NVE21772  Xesp_000023 Hvul_g15501_1
# 13      Spis_XP_022786829_1 Nvec_v1g112864 Xesp_000028 Hvul_g15231_1
# ...
